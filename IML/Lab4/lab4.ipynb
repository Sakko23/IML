# %%
import pandas as pd

operations = pd.read_csv('./1 - operations.csv', sep = ',')
# operations.datetime = pd.to_datetime(operations.datetime)
operations[operations['code'] == 6011]
# Out:
#          client_id      datetime  code  type         sum source_id
# 0         96372458  421 06:33:15  6011  2010  -561478.94    256572
# 1         64404394  399 06:56:49  6011  2010   -67377.47    330228
# 2         24567813  377 17:20:40  6011  7010    67377.47    542191
# 3         21717441   55 13:38:47  6011  2010   -44918.32       NaN
# 4         14331004  263 12:57:08  6011  2010 -3368873.66    980531
# 16         2750594  246 07:19:23  6011  2010   -22459.16    570035
# 18         2444292  355 09:47:45  6011  2010   -65131.56    744190
# 31        82840746  454 18:49:24  6011  7010   134754.95    536402
# 34         2132533  184 20:09:07  6011  2010  -224591.58       NaN
# 36        20166346  404 16:32:48  6011  2010   -22459.16    261072
# 43        74334566  187 16:36:30  6011  7010   134754.95       NaN
# 54        28558979   41 06:09:09  6011  2011   -89836.63       NaN
# 57        35361066  295 21:09:28  6011  2010    -6737.75    518694
# 61        63974778  291 02:31:41  6011  2010   -67377.47    366324
# 67         8552161  156 09:53:16  6011  2010    -8983.66       NaN
# 71        32250029    5 18:47:13  6011  2010  -105558.04       NaN
# 73        43892754  280 17:36:16  6011  2010  -224591.58    472219
# 77        68955791   59 21:24:51  6011  2010   -35934.65       NaN
# 81        13595171   55 11:43:08  6011  2010  -381805.68       NaN
# 83        60991319  186 14:45:16  6011  2010   -22459.16       NaN
# 85        29326500  284 13:20:59  6011  2010    -6737.75    796501
# 92        75615871  131 18:35:28  6011  2010  -123525.37       NaN
# 94        71973473  325 10:49:04  6011  2010   -20213.24    370104
# 95        30739309   61 09:22:43  6011  2010   -22459.16       NaN
# 98        49760703   94 18:56:40  6011  7010    22459.16       NaN
# 99        60412759  188 12:36:01  6011  2010   -89836.63       NaN
# 107       38896722  394 09:10:18  6011  2010  -348116.94    363774
# 117       83939025  277 14:41:52  6011  7010    67377.47    389371
# 119       67984042  174 12:57:15  6011  2010  -168443.68       NaN
# 125         529504  113 17:32:55  6011  2010 -1111728.31       NaN
# ...            ...           ...   ...   ...         ...       ...
# 5393185   40508757  406 14:08:27  6011  2010  -202132.42    140287
# 5393187   16233088  454 19:04:54  6011  7011   336887.37    391714
# 5393207   48618305   21 08:51:56  6011  2010   -42672.40       NaN
# 5393208   83571433  426 10:25:16  6011  2010   -22459.16    450347
# 5393209   56687390    4 00:11:30  6011  2010   -11229.58       NaN
# 5393213   89498932    6 20:42:54  6011  2010   -33688.74       NaN
# 5393214   61980854  194 08:41:06  6011  2010   -89836.63       NaN
# 5393216   69782822   56 14:54:19  6011  2010   -11229.58       NaN
# 5393219   25377986  279 09:13:00  6011  2010  -673774.73     70001
# 5393223   46837651  179 11:03:40  6011  2010  -280739.47       NaN
# 5393224   38709240  222 09:25:41  6011  7010   134754.95    804906
# 5393226   79234200  444 10:59:27  6011  7010    11229.58     90742
# 5393231   88850073  272 08:10:24  6011  2010  -314428.21    890175
# 5393232   11653939  328 17:21:25  6011  2010  -112295.79    640491
# 5393235   32713709  232 11:59:56  6011  2010   -38180.57    980242
# 5393245   98998782  290 02:54:21  6011  2010   -22459.16    119973
# 5393258   78858518  168 15:45:32  6011  2010   -22459.16       NaN
# 5393266   43777193  283 10:30:50  6011  2011   -89836.63    829990
# 5393272   46392653   48 14:11:18  6011  2010   -11229.58       NaN
# 5393275    2952449   73 08:04:39  6011  7010    89836.63       NaN
# 5393279   99785861  334 10:06:28  6011  2010  -224591.58    660802
# 5393288   54441407  265 13:48:00  6011  7010    33688.74     82037
# 5393291   91437038   74 10:05:29  6011  7010   808529.68       NaN
# 5393295   73025235  330 11:28:01  6011  2010    -4491.83    392681
# 5393304   32587301  426 12:22:10  6011  2010   -22459.16    151302
# 5393309   49914960  103 18:32:49  6011  7010    44918.32       NaN
# 5393310   62225605  209 14:35:45  6011  2010  -123525.37    610188
# 5393314   76096102  110 11:30:27  6011  2010   -96574.38       NaN
# 5393318   64504493  104 12:34:53  6011  2010  -134754.95       NaN
# 5393321   33342698   36 14:17:23  6011  7010   112295.79       NaN
#
# [1157630 rows x 6 columns]

# %%
dataset = pd.read_csv('./2 - dataset.csv', sep = ',')
dataset[:4]
# Out:
#    client_id  status
# 0   31984797       1
# 1   95623488       1
# 2   21248516       1
# 3   83228517       1

# %%
types = pd.read_csv('./3 - types.csv', sep = ';')
types[:4]
# Out:
#    type                                   type_description
# 0  8001                      Установление расх. лимита по
# 1  2411  Перевод с карты на счет др.лица в одном тер. б...
# 2  4035                                                н/д
# 3  3001            Комиссия за обслуживание ссудного счета

# %%
codes = pd.read_csv('./4 - codes.csv', sep = ';')
codes[:4]
# Out:
#    code                                   code_description
# 0  5944  Магазины по продаже часов, ювелирных изделий и...
# 1  5621                             Готовая женская одежда
# 2  5697       Услуги по переделке, починке и пошиву одежды
# 3  7995                       Транзакции по азартным играм

# %%
op_ty = pd.merge(operations, types, on = 'type')
allsets = pd.merge(op_ty, codes, on = 'code')
allsets[:3]
# Out:
#    client_id      datetime  code  type        sum source_id  \
# 0   96372458  421 06:33:15  6011  2010 -561478.94    256572
# 1   64404394  399 06:56:49  6011  2010  -67377.47    330228
# 2   21717441   55 13:38:47  6011  2010  -44918.32       NaN
#
#                         type_description  \
# 0  Выдача наличных в АТМ Сбербанк России
# 1  Выдача наличных в АТМ Сбербанк России
# 2  Выдача наличных в АТМ Сбербанк России
#
#                                     code_description
# 0  Финансовые институты — снятие наличности автом...
# 1  Финансовые институты — снятие наличности автом...
# 2  Финансовые институты — снятие наличности автом...

# %%
import numpy as np
import matplotlib.pyplot as plt

allsets['client_id'].hist(bins=50,color = 'yellow')
plt.xlim(0,90000000)
plt.show()

# %%
allsets['code'].hist(bins=50,color = 'blue')
plt.show()

# %%
allsets['type'].hist(bins=50,color = 'green')
plt.show()

# %%
allsets['sum'].hist(bins=50,color = 'orange')
plt.xlim(-1000000,1000000)
plt.show()
